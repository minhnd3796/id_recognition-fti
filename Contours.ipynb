# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Get current size
fig_size = plt.rcParams["figure.figsize"]
 
# Prints: [8.0, 6.0]
print("Current size:", fig_size)

fig_size[0] = fig_size[0] * 2
fig_size[1] = fig_size[1] * 2
plt.rcParams["figure.figsize"] = fig_size
print("Current size:", fig_size)
# Out:
# Current size: [6.0, 4.0]
# Current size: [12.0, 8.0]

# %%
img = cv2.imread('two_contours.png', 0)
_, thresh = cv2.threshold(img, 127, 255, 0)
plt.imshow(thresh, cmap = 'gray', interpolation = 'bicubic')
# plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis

# for i in range(84):
#     for j in range(753):
#         if (thresh[i, j] != 0 and thresh[i, j] != 255):
#             print(thresh[i, j])

# %%
plt.imshow(thresh, cmap = 'gray', interpolation = 'bicubic')
# plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()

# %%
img = cv2.imread('two_contours.png', 0)
_, thresh = cv2.threshold(img, 127, 255, 0)
im2,contours,hierarchy = cv2.findContours(thresh, 1, 2)

# cnt = contours[1]
# print(type(contours))

# x,y,w,h = cv2.boundingRect(cnt)
# cv2.rectangle(thresh, (x, y),(x + w, y + h), (255, 255, 255), 2)

# rect = cv2.minAreaRect(cnt)
# box = cv2.boxPoints(rect)
# box = np.int0(box)
# cv2.drawContours(thresh, [box], 0, (127, 127, 127), 2)

# cv2.drawContours(thresh, contours, -1, (127, 127, 127), 3)
# cv2.drawContours(thresh, contours, 3, (127, 127, 127), 3)
# cv2.drawContours(thresh, [cnt], 0, (127, 127, 127), 3)

for cnt in contours:
    x,y,w,h = cv2.boundingRect(cnt)
    print(x, y, w, h)
    cv2.rectangle(thresh, (x, y),(x + int(w), y + int(h)), (127, 127, 127), 0)

# print(len(contours))
plt.imshow(thresh, cmap = 'gray', interpolation = 'bicubic')
# plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()
# for i in range(84):
#     for j in range(753):
#         if (thresh[i, j] != 0 and thresh[i, j] != 255):
#             print(thresh[i, j])
# Out:
# 33 165 131 120
# 146 39 130 121

# %%
print(img.shape)
plt.imshow(img[165:165+120+1,33:33+131+1], cmap = 'gray', interpolation = 'bicubic')
# Out:
# (300, 300)

# %%
print(img.shape)
plt.imshow(img[39:39+121+1,146:146+130+1], cmap = 'gray', interpolation = 'bicubic')
cv2.imwrite("digits/cropped.png", img[39:39+121+1,146:146+130+1])
# Out:
# (300, 300)
# True
